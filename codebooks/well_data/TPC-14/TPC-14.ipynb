# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ## TPC-14
#
# Coordinates: x = 335446.971, y = 4264046.019, z = 1675.199038, depth = 145 m
#
# Lithology:

# %%
depth = 145
start_x = 335446.971
start_y = 4264046.019
start_z = 1675.199038

r = np.arange(0.0, depth + 0.5, 0.5)
phi = np.zeros(len(r))
theta = np.zeros(len(r))

# %%
for x in range(0, len(r)):
    theta[x] = -90

# %%
#Well trajectory

fig = plt.figure(figsize = (12,12))

ax = fig.add_subplot(111, projection = '3d')

# get lengths of the separate segments 
r[1:] = r[1:] - r[:-1]
# convert to radians
phi = phi * 2 * np.pi / 360.
theta = (90-theta) * 2 * np.pi / 360.
# get x, y, z from known formulae
x = start_x + (r*np.cos(phi)*np.sin(theta))
y = start_y + (r*np.sin(phi)*np.sin(theta))
z = (r*np.cos(theta))

# np.cumsum is employed to gradually sum resultant vectors 
ax.plot(np.cumsum(x),np.cumsum(y),np.cumsum(z))


plt.show()

# %%
elevation = np.cumsum(z) + start_z

# %%
import vtki

well_traj_adam = vtki.PolyData(np.c_[x,y,elevation])
well_traj_adam.save('well_TPC14.vtk')

# %%
well_traj_adam.plot()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x116B00978>
