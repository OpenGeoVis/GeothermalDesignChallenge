# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ## Dec-35
#
# Coordinates: x = 339385.01, y = 4264212.985, z =	1880.635342
#
# Lithology: Basin Fill (0-78m), Granitoid (78-2133.6)
#
# Depth: 2133.6 m

# %%
depth = 2133.6
start_x = 339385.01
start_y = 4264212.985
start_z = 1880.635342

r = np.arange(0.0, depth + 0.5, 0.5)
phi = np.zeros(len(r))
theta = np.zeros(len(r))   

for x in range(0, len(r)):
    theta[x] = -90

#Well trajectory

# get lengths of the separate segments 
r[1:] = r[1:] - r[:-1]
# convert to radians
phi = phi * 2 * np.pi / 360.
theta = (90-theta) * 2 * np.pi / 360.
# get x, y, z from known formulae
x = start_x + (r*np.cos(phi)*np.sin(theta))
y = start_y + (r*np.sin(phi)*np.sin(theta))
z = (r*np.cos(theta))

# np.cumsum is employed to gradually sum resultant vectors 
#ax.plot(np.cumsum(x),np.cumsum(y),np.cumsum(z))


#plt.show()

# %%
elevation = np.cumsum(z) + start_z

import vtki

well_traj_adam = vtki.PolyData(np.c_[x,y,elevation])
well_traj_adam.save('well_DEC35.vtk')

well_traj_adam.plot()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x13E488208>

# %% [markdown]
# ## 13-10
#
# Coordinates: x = 337709.018, y=4260659.997, z =	1796.263259
#
# Lithology: Basin Fill (0-75 m), Granitoid(75-1601.3 m)
#
# Depth: 1601.3 m

# %%
depth = 1601.3
start_x = 337709.018
start_y = 4260659.997
start_z = 1796.263259

r = np.arange(0.0, depth + 0.5, 0.5)
phi = np.zeros(len(r))
theta = np.zeros(len(r))   

for x in range(0, len(r)):
    theta[x] = -90

#Well trajectory

# get lengths of the separate segments 
r[1:] = r[1:] - r[:-1]
# convert to radians
phi = phi * 2 * np.pi / 360.
theta = (90-theta) * 2 * np.pi / 360.
# get x, y, z from known formulae
x = start_x + (r*np.cos(phi)*np.sin(theta))
y = start_y + (r*np.sin(phi)*np.sin(theta))
z = (r*np.cos(theta))

# np.cumsum is employed to gradually sum resultant vectors

# %%
elevation = np.cumsum(z) + start_z

import vtki

well_traj_adam = vtki.PolyData(np.c_[x,y,elevation])
well_traj_adam.save('well_1310.vtk')

well_traj_adam.plot()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x12A7E3748>

# %% [markdown]
# ## 14-2
#
# Coordinates: x = 339393.002, y=4262171.961, z =	1903.453009
#
# Lithology: Basin Fill (0-76m), Granitoid (76-1808.5 m)
#
# Depth: 1808.5 m

# %%
depth = 1808.5
start_x = 339393.002
start_y = 4262171.961
start_z = 1903.453009

r = np.arange(0.0, depth + 0.5, 0.5)
phi = np.zeros(len(r))
theta = np.zeros(len(r))   

for x in range(0, len(r)):
    theta[x] = -90

#Well trajectory

# get lengths of the separate segments 
r[1:] = r[1:] - r[:-1]
# convert to radians
phi = phi * 2 * np.pi / 360.
theta = (90-theta) * 2 * np.pi / 360.
# get x, y, z from known formulae
x = start_x + (r*np.cos(phi)*np.sin(theta))
y = start_y + (r*np.sin(phi)*np.sin(theta))
z = (r*np.cos(theta))

# %%
elevation = np.cumsum(z) + start_z

import vtki

well_traj_adam = vtki.PolyData(np.c_[x,y,elevation])
well_traj_adam.save('well_142.vtk')

well_traj_adam.plot()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x13D7BCE10>

# %% [markdown]
# ## 24-36
#
# Coordinates: x = 341221.016, y =4263743.011, z =	2034.161472
#
# Lithology: Basin Fill (0-92 m), Granitoid (92-1819.7 m)
#
# Depth: 1819.7 m

# %%
depth = 1819.7
start_x = 341221.016
start_y = 4263743.011
start_z = 2034.161472

r = np.arange(0.0, depth + 0.5, 0.5)
phi = np.zeros(len(r))
theta = np.zeros(len(r))   

for x in range(0, len(r)):
    theta[x] = -90

#Well trajectory

# get lengths of the separate segments 
r[1:] = r[1:] - r[:-1]
# convert to radians
phi = phi * 2 * np.pi / 360.
theta = (90-theta) * 2 * np.pi / 360.
# get x, y, z from known formulae
x = start_x + (r*np.cos(phi)*np.sin(theta))
y = start_y + (r*np.sin(phi)*np.sin(theta))
z = (r*np.cos(theta))

# %%
elevation = np.cumsum(z) + start_z

import vtki

well_traj_adam = vtki.PolyData(np.c_[x,y,elevation])
well_traj_adam.save('well_2436.vtk')

well_traj_adam.plot()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x13E491358>

# %% [markdown]
# ## 25-15
#
# Coordinates: x = 337873.021, y=4258706.959, z =	1827.029208
#
# Lithology: Basin Fill (0-110m), Granitoid(110-2287.5 m)
#
# Depth: 2287.5 m

# %%
depth = 2287.5
start_x = 337873.021
start_y = 4258706.959
start_z = 1827.029208

r = np.arange(0.0, depth + 0.5, 0.5)
phi = np.zeros(len(r))
theta = np.zeros(len(r))   

for x in range(0, len(r)):
    theta[x] = -90

#Well trajectory

# get lengths of the separate segments 
r[1:] = r[1:] - r[:-1]
# convert to radians
phi = phi * 2 * np.pi / 360.
theta = (90-theta) * 2 * np.pi / 360.
# get x, y, z from known formulae
x = start_x + (r*np.cos(phi)*np.sin(theta))
y = start_y + (r*np.sin(phi)*np.sin(theta))
z = (r*np.cos(theta))

# %%
elevation = np.cumsum(z) + start_z

import vtki

well_traj_adam = vtki.PolyData(np.c_[x,y,elevation])
well_traj_adam.save('well_2515.vtk')

well_traj_adam.plot()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x12A7E3780>

# %% [markdown]
# ## 28-3
#
# Coordinates: x = 337980.006, y=4261383.036, z =	1821.542636
#
# Lithology: Basin Fill (0-100 m), Granitoid(100-1143 m)
#
# Depth: 1143 m

# %%
depth = 1143
start_x = 337980.006
start_y = 4261383.036
start_z = 1821.542636

r = np.arange(0.0, depth + 0.5, 0.5)
phi = np.zeros(len(r))
theta = np.zeros(len(r))   

for x in range(0, len(r)):
    theta[x] = -90

#Well trajectory
# get lengths of the separate segments 
r[1:] = r[1:] - r[:-1]
# convert to radians
phi = phi * 2 * np.pi / 360.
theta = (90-theta) * 2 * np.pi / 360.
# get x, y, z from known formulae
x = start_x + (r*np.cos(phi)*np.sin(theta))
y = start_y + (r*np.sin(phi)*np.sin(theta))
z = (r*np.cos(theta))

# %%
elevation = np.cumsum(z) + start_z

import vtki

well_traj_adam = vtki.PolyData(np.c_[x,y,elevation])
well_traj_adam.save('well_283.vtk')

well_traj_adam.plot()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x13E4887F0>

# %% [markdown]
# ## Mar-1
#
# Coordinates: x = 338594.958, y=4262043.98, z=1863.393859
#
# Lithology: Basin Fill(0-201 m), Granitoid (201-815.3 m)
#
# Depth: 815.3 m

# %%
depth = 815.3
start_x = 338594.958
start_y = 4262043.98
start_z = 1863.393859

r = np.arange(0.0, depth + 0.5, 0.5)
phi = np.zeros(len(r))
theta = np.zeros(len(r))   

for x in range(0, len(r)):
    theta[x] = -90

#Well trajectory


# get lengths of the separate segments 
r[1:] = r[1:] - r[:-1]
# convert to radians
phi = phi * 2 * np.pi / 360.
theta = (90-theta) * 2 * np.pi / 360.
# get x, y, z from known formulae
x = start_x + (r*np.cos(phi)*np.sin(theta))
y = start_y + (r*np.sin(phi)*np.sin(theta))
z = (r*np.cos(theta))

# %%
elevation = np.cumsum(z) + start_z

import vtki

well_traj_adam = vtki.PolyData(np.c_[x,y,elevation])
well_traj_adam.save('well_Mar1.vtk')

well_traj_adam.plot()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x13E4880F0>

# %% [markdown]
# ## 35-3
#
# Coordinates: x = 338165.011, y=4261915.973, z=	1840.914448
#
# Lithology: Basin Fill (0-300 m), Granitoid (300-381 m)
#
# Depth: 381 m

# %%
depth = 381
start_x = 338165.011
start_y = 4261915.973
start_z = 1840.914448

r = np.arange(0.0, depth + 0.5, 0.5)
phi = np.zeros(len(r))
theta = np.zeros(len(r))   

for x in range(0, len(r)):
    theta[x] = -90

#Well trajectory


# get lengths of the separate segments 
r[1:] = r[1:] - r[:-1]
# convert to radians
phi = phi * 2 * np.pi / 360.
theta = (90-theta) * 2 * np.pi / 360.
# get x, y, z from known formulae
x = start_x + (r*np.cos(phi)*np.sin(theta))
y = start_y + (r*np.sin(phi)*np.sin(theta))
z = (r*np.cos(theta))

elevation = np.cumsum(z) + start_z

import vtki

well_traj_adam = vtki.PolyData(np.c_[x,y,elevation])
well_traj_adam.save('well_353.vtk')

well_traj_adam.plot()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x13D7BCF98>

# %% [markdown]
# ## 52-21
#
# Coordinates: x = 336906.016, y=4257739.008, z= 1783.045663
#
# Lithology: Basin Fill (0-177m), Granitoid(177-2247.5 m)
#
# Depth: 2247.5 m

# %%
depth = 2247.5
start_x = 336906.016
start_y = 4257739.008
start_z = 1783.045663

r = np.arange(0.0, depth + 0.5, 0.5)
phi = np.zeros(len(r))
theta = np.zeros(len(r))   

for x in range(0, len(r)):
    theta[x] = -90

#Well trajectory


# get lengths of the separate segments 
r[1:] = r[1:] - r[:-1]
# convert to radians
phi = phi * 2 * np.pi / 360.
theta = (90-theta) * 2 * np.pi / 360.
# get x, y, z from known formulae
x = start_x + (r*np.cos(phi)*np.sin(theta))
y = start_y + (r*np.sin(phi)*np.sin(theta))
z = (r*np.cos(theta))

# %%
elevation = np.cumsum(z) + start_z

import vtki

well_traj_adam = vtki.PolyData(np.c_[x,y,elevation])
well_traj_adam.save('well_5221.vtk')

well_traj_adam.plot()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x12A7E37B8>

# %% [markdown]
# ## 54-3
#
# Coordinates: x = 338607.001, y=4262195.945, z=	1862.947531
#
# Lithology: Basin Fill (0-123m), Granitoid (123-853.4m)
#
# Depth: 853.4 m

# %%
depth = 853.4
start_x = 338607.001
start_y = 4262195.945
start_z = 1862.947531

r = np.arange(0.0, depth + 0.5, 0.5)
phi = np.zeros(len(r))
theta = np.zeros(len(r))   

for x in range(0, len(r)):
    theta[x] = -90

#Well trajectory

# get lengths of the separate segments 
r[1:] = r[1:] - r[:-1]
# convert to radians
phi = phi * 2 * np.pi / 360.
theta = (90-theta) * 2 * np.pi / 360.
# get x, y, z from known formulae
x = start_x + (r*np.cos(phi)*np.sin(theta))
y = start_y + (r*np.sin(phi)*np.sin(theta))
z = (r*np.cos(theta))

# %%
elevation = np.cumsum(z) + start_z

import vtki

well_traj_adam = vtki.PolyData(np.c_[x,y,elevation])
well_traj_adam.save('well_543.vtk')

well_traj_adam.plot()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x12E0F60F0>

# %% [markdown]
# ## 71-10
#
# Coordinates: x = 338913.04, y=4261094.037, z= 1864.439098
#
# Lithology: Basin Fill (0-120m), Granitoid(120-1977.8m)
#
# Depth: 1977.8 m

# %%
depth = 1977.8
start_x = 338913.04
start_y = 4261094.037
start_z = 1864.439098

r = np.arange(0.0, depth + 0.5, 0.5)
phi = np.zeros(len(r))
theta = np.zeros(len(r))   

for x in range(0, len(r)):
    theta[x] = -90

#Well trajectory
# get lengths of the separate segments 
r[1:] = r[1:] - r[:-1]
# convert to radians
phi = phi * 2 * np.pi / 360.
theta = (90-theta) * 2 * np.pi / 360.
# get x, y, z from known formulae
x = start_x + (r*np.cos(phi)*np.sin(theta))
y = start_y + (r*np.sin(phi)*np.sin(theta))
z = (r*np.cos(theta))

# %%
elevation = np.cumsum(z) + start_z

import vtki

well_traj_adam = vtki.PolyData(np.c_[x,y,elevation])
well_traj_adam.save('well_7110.vtk')

well_traj_adam.plot()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x12E0F6048>

# %% [markdown]
# ## 72-16
#
# Coordinates: x = 337321.03, y=4259298.972, z =1795.135846
#
# Lithology: Basin Fill (0-148m), Granitoid (148-422.8m)
#
# Depth: 422.8 m

# %% [markdown]
# ## 82-33
#
# Coordinates: x = 337682.986, y=4264131.015, z=1777.602847
#
# Lithology: Basin Fill (0-104m), Granitoid (104-1767.8 m)
#
# Depth: 1767.8 m

# %%
depth = 1767.8
start_x = 337682.986
start_y = 4264131.015
start_z = 1777.602847

r = np.arange(0.0, depth + 0.5, 0.5)
phi = np.zeros(len(r))
theta = np.zeros(len(r))   

for x in range(0, len(r)):
    theta[x] = -90

#Well trajectory

# get lengths of the separate segments 
r[1:] = r[1:] - r[:-1]
# convert to radians
phi = phi * 2 * np.pi / 360.
theta = (90-theta) * 2 * np.pi / 360.
# get x, y, z from known formulae
x = start_x + (r*np.cos(phi)*np.sin(theta))
y = start_y + (r*np.sin(phi)*np.sin(theta))
z = (r*np.cos(theta))

# %%
elevation = np.cumsum(z) + start_z

import vtki

well_traj_adam = vtki.PolyData(np.c_[x,y,elevation])
well_traj_adam.save('well_8233.vtk')

well_traj_adam.plot()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x137265630>

# %% [markdown]
# ## 1-Sept
#
# Coordinates: x = 336841.969, y=4260929.031, z=1776.614561
#
# Lithology: Basin Fill (0-215m), Granitoid (215-2122.4 m)
#
# Depth: 2122.4 m

# %%
depth = 2122.4
start_x = 336841.969
start_y = 4260929.031
start_z = 1776.614561

r = np.arange(0.0, depth + 0.5, 0.5)
phi = np.zeros(len(r))
theta = np.zeros(len(r))   

for x in range(0, len(r)):
    theta[x] = -90

#Well trajectory

# get lengths of the separate segments 
r[1:] = r[1:] - r[:-1]
# convert to radians
phi = phi * 2 * np.pi / 360.
theta = (90-theta) * 2 * np.pi / 360.
# get x, y, z from known formulae
x = start_x + (r*np.cos(phi)*np.sin(theta))
y = start_y + (r*np.sin(phi)*np.sin(theta))
z = (r*np.cos(theta))

# %%
elevation = np.cumsum(z) + start_z

import vtki

well_traj_adam = vtki.PolyData(np.c_[x,y,elevation])
well_traj_adam.save('well_Sept1.vtk')

well_traj_adam.plot()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x13E439978>

# %% [markdown]
# ## Acord-1
#
# Coordinates: x = 330059.033, y=4265084.001, z=1518.831911
#
# Lithology: Basin Fill (0-2163m), Lava-Tuffs (2163-2438m), Volcaniclastic (2438-3110m), Granitoid (3110 - 3855.7m)
#
# Depth: 3855.7 m

# %%
depth = 3855.7
start_x = 330059.033
start_y = 4265084.001
start_z = 1518.831911

r = np.arange(0.0, depth + 0.5, 0.5)
phi = np.zeros(len(r))
theta = np.zeros(len(r))   

for x in range(0, len(r)):
    theta[x] = -90

#Well trajectory

# get lengths of the separate segments 
r[1:] = r[1:] - r[:-1]
# convert to radians
phi = phi * 2 * np.pi / 360.
theta = (90-theta) * 2 * np.pi / 360.
# get x, y, z from known formulae
x = start_x + (r*np.cos(phi)*np.sin(theta))
y = start_y + (r*np.sin(phi)*np.sin(theta))
z = (r*np.cos(theta))

# %%
elevation = np.cumsum(z) + start_z

import vtki

well_traj_adam = vtki.PolyData(np.c_[x,y,elevation])
well_traj_adam.save('well_Acord1.vtk')

well_traj_adam.plot()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x13E447CF8>

# %% [markdown]
# ## Big Cedar Cove UU-76
#
# Coordinates: x =339669.042, y=4258810.021, z=1974.568122
# Lithology: Basin Fill
#
# Depth: 100 m

# %%
depth = 100
start_x = 339669.042
start_y = 4258810.021
start_z = 1974.568122

r = np.arange(0.0, depth + 0.5, 0.5)
phi = np.zeros(len(r))
theta = np.zeros(len(r))   

for x in range(0, len(r)):
    theta[x] = -90

#Well trajectory

# get lengths of the separate segments 
r[1:] = r[1:] - r[:-1]
# convert to radians
phi = phi * 2 * np.pi / 360.
theta = (90-theta) * 2 * np.pi / 360.
# get x, y, z from known formulae
x = start_x + (r*np.cos(phi)*np.sin(theta))
y = start_y + (r*np.sin(phi)*np.sin(theta))
z = (r*np.cos(theta))

elevation = np.cumsum(z) + start_z

import vtki

well_traj_adam = vtki.PolyData(np.c_[x,y,elevation])
well_traj_adam.save('well_BigCedar.vtk')

well_traj_adam.plot()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x134CCF908>

# %% [markdown]
# ## EV-4113
#
# Coordinates: x =340211.039, y=4254110.963, z=2060.215218
#
# Lithology: Granitoid
#
# Depth: 36 m

# %%
depth = 36
start_x = 340211.039
start_y = 4254110.963
start_z = 2060.215218

r = np.arange(0.0, depth + 0.5, 0.5)
phi = np.zeros(len(r))
theta = np.zeros(len(r))   

for x in range(0, len(r)):
    theta[x] = -90

#Well trajectory

# get lengths of the separate segments 
r[1:] = r[1:] - r[:-1]
# convert to radians
phi = phi * 2 * np.pi / 360.
theta = (90-theta) * 2 * np.pi / 360.
# get x, y, z from known formulae
x = start_x + (r*np.cos(phi)*np.sin(theta))
y = start_y + (r*np.sin(phi)*np.sin(theta))
z = (r*np.cos(theta))

elevation = np.cumsum(z) + start_z

import vtki

well_traj_adam = vtki.PolyData(np.c_[x,y,elevation])
well_traj_adam.save('well_EV4113.vtk')

well_traj_adam.plot()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x12E0F6160>

# %% [markdown]
# ## EV-4115
#
# Coordinates: x =339925.996, y=4253546.002, z=1986.095352
#
# Lithology: Granitoid
#
# Depth: 70 m

# %%
depth = 70
start_x = 339925.996
start_y = 4253546.002
start_z = 1986.095352

r = np.arange(0.0, depth + 0.5, 0.5)
phi = np.zeros(len(r))
theta = np.zeros(len(r))   

for x in range(0, len(r)):
    theta[x] = -90

#Well trajectory

# get lengths of the separate segments 
r[1:] = r[1:] - r[:-1]
# convert to radians
phi = phi * 2 * np.pi / 360.
theta = (90-theta) * 2 * np.pi / 360.
# get x, y, z from known formulae
x = start_x + (r*np.cos(phi)*np.sin(theta))
y = start_y + (r*np.sin(phi)*np.sin(theta))
z = (r*np.cos(theta))

elevation = np.cumsum(z) + start_z

import vtki

well_traj_adam = vtki.PolyData(np.c_[x,y,elevation])
well_traj_adam.save('well_EV4115.vtk')

well_traj_adam.plot()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x13402C6A0>

# %% [markdown]
# ## GPC-1
#
# Coordinates: x =331750.971, y=4253210.946, z=1627.260902
#
# Lithology: Basin Fill
#
# Depth: 109 m

# %% [markdown]
# ## GPC-10
#
# Coordinates: x =343067.984, y=4270958.977, z=1692.86
#
# Lithology: Granitoid
#
# Depth: 60 m

# %%
depth = 60
start_x = 343067.984
start_y = 4270958.977
start_z = 1692.86

r = np.arange(0.0, depth + 0.5, 0.5)
phi = np.zeros(len(r))
theta = np.zeros(len(r))   

for x in range(0, len(r)):
    theta[x] = -90

#Well trajectory

# get lengths of the separate segments 
r[1:] = r[1:] - r[:-1]
# convert to radians
phi = phi * 2 * np.pi / 360.
theta = (90-theta) * 2 * np.pi / 360.
# get x, y, z from known formulae
x = start_x + (r*np.cos(phi)*np.sin(theta))
y = start_y + (r*np.sin(phi)*np.sin(theta))
z = (r*np.cos(theta))

elevation = np.cumsum(z) + start_z

import vtki

well_traj_adam = vtki.PolyData(np.c_[x,y,elevation])
well_traj_adam.save('well_GPC10.vtk')

well_traj_adam.plot()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x13CB26748>

# %% [markdown]
# ## GPC-14
#
# Coordinates: x =334500.009, y=4258223.956, z=1690.961124
#
# Lithology: Basin Fill
#
# Depth: 160 m

# %% [markdown]
# ## GPC-15
#
# Coordinates: x =334303.988, y=4258057.022, z=1688.434742
#
# Lithology: Basin Fill
#
# Depth: 576.2 m

# %%
depth = 576.2
start_x = 334303.988
start_y = 4258057.022
start_z = 1688.434742

r = np.arange(0.0, depth + 0.5, 0.5)
phi = np.zeros(len(r))
theta = np.zeros(len(r))   

for x in range(0, len(r)):
    theta[x] = -90

#Well trajectory

# get lengths of the separate segments 
r[1:] = r[1:] - r[:-1]
# convert to radians
phi = phi * 2 * np.pi / 360.
theta = (90-theta) * 2 * np.pi / 360.
# get x, y, z from known formulae
x = start_x + (r*np.cos(phi)*np.sin(theta))
y = start_y + (r*np.sin(phi)*np.sin(theta))
z = (r*np.cos(theta))

elevation = np.cumsum(z) + start_z

import vtki

well_traj_adam = vtki.PolyData(np.c_[x,y,elevation])
well_traj_adam.save('well_GPC15.vtk')

well_traj_adam.plot()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x13E491320>

# %% [markdown]
# ## GPC-2
#
# Coordinates: x =333776.983, y=4253152.973, z=1703.975904
#
# Lithology: Basin Fill
#
# Depth: 91 m

# %% [markdown]
# ## GPC-3
#
# Coordinates: x =335962, y=4253027.987, z=1798.094364
#
# Lithology: Basin Fill
#
# Depth: 90 m

# %% [markdown]
# ## GPC-4
#
# Coordinates: x =336426.977, y=4254695.03, z=1799.023463
#
# Lithology: Basin Fill
#
# Depth: 90 m

# %% [markdown]
# ## GPC-5
#
# Coordinates: x =338323.003, y=4254699.997, z=1895.057223
#
# Lithology: Basin Fill
#
# Depth: 56 m

# %% [markdown]
# ## GPC-6
# Coordinates: x =332001.017, y=4255968.972, z=1637.755532
#
# Lithology: Basin Fill
#
# Depth: 91 m

# %% [markdown]
# ## GPC-7
# Coordinates: x =340897.969, y=4258876.957, z=2125.254514
#
# Lithology: Basin Fill
#
# Depth: 94 m

# %% [markdown]
# ## GPC-8
# Coordinates: x =340917.03, y=4264750.974, z=2022.908072
#
# Lithology: Basin Fill
#
# Depth: 124 m

# %% [markdown]
# ## GPC-9
# Coordinates: x =341551.013, y=4269454.034, z=2018.508758
#
# Lithology: Granitoid
#
# Depth: 90 m

# %%
depth = 90
start_x = 341551.013
start_y = 4269454.034
start_z = 2018.508758

r = np.arange(0.0, depth + 0.5, 0.5)
phi = np.zeros(len(r))
theta = np.zeros(len(r))   

for x in range(0, len(r)):
    theta[x] = -90

#Well trajectory

# get lengths of the separate segments 
r[1:] = r[1:] - r[:-1]
# convert to radians
phi = phi * 2 * np.pi / 360.
theta = (90-theta) * 2 * np.pi / 360.
# get x, y, z from known formulae
x = start_x + (r*np.cos(phi)*np.sin(theta))
y = start_y + (r*np.sin(phi)*np.sin(theta))
z = (r*np.cos(theta))

elevation = np.cumsum(z) + start_z

import vtki

well_traj_adam = vtki.PolyData(np.c_[x,y,elevation])
well_traj_adam.save('well_GPC9.vtk')

well_traj_adam.plot()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x1372657F0>

# %% [markdown]
# ## McCullough
# Coordinates: x =330055.015, y=4265022.022, z=1519.401151
#
# Lithology: Basin Fill
#
# Depth: 105 m

# %% [markdown]
# ## MM-101
# Coordinates: x =344017.017, y=4262224.962, z=2194.617684
#
# Lithology: Granitoid
#
# Depth: 50 m

# %%
depth = 50
start_x = 344017.017
start_y = 4262224.962
start_z = 2194.617684

r = np.arange(0.0, depth + 0.5, 0.5)
phi = np.zeros(len(r))
theta = np.zeros(len(r))   

for x in range(0, len(r)):
    theta[x] = -90

#Well trajectory

# get lengths of the separate segments 
r[1:] = r[1:] - r[:-1]
# convert to radians
phi = phi * 2 * np.pi / 360.
theta = (90-theta) * 2 * np.pi / 360.
# get x, y, z from known formulae
x = start_x + (r*np.cos(phi)*np.sin(theta))
y = start_y + (r*np.sin(phi)*np.sin(theta))
z = (r*np.cos(theta))

elevation = np.cumsum(z) + start_z

import vtki

well_traj_adam = vtki.PolyData(np.c_[x,y,elevation])
well_traj_adam.save('well_MM101.vtk')

well_traj_adam.plot()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x1314D2518>

# %% [markdown]
# ## MV-125
# Coordinates: x =335553.983, y=4254096.999, z=1725.010642
#
# Lithology: Basin Fill
#
# Depth: 36 m

# %% [markdown]
# ## MV-22
# Coordinates: x =323737.995, y=4260569.95, z=1506.93
#
# Lithology: Basin Fill
#
# Depth: 90.2 m

# %% [markdown]
# ## MV-23
# Coordinates: x =322497.02, y=4267508.027, z=1726.69
#
# Lithology: Basin Fill
#
# Depth: 123.7 m

# %% [markdown]
# ## OH-1
# Coordinates: x =335529.984, y=4259049.011, z=1715.484989
#
# Lithology: Basin Fill
#
# Depth: 706.2 m

# %%
depth = 706.2
start_x = 335529.984
start_y = 4259049.011
start_z = 1715.484989

r = np.arange(0.0, depth + 0.5, 0.5)
phi = np.zeros(len(r))
theta = np.zeros(len(r))   

for x in range(0, len(r)):
    theta[x] = -90

#Well trajectory

# get lengths of the separate segments 
r[1:] = r[1:] - r[:-1]
# convert to radians
phi = phi * 2 * np.pi / 360.
theta = (90-theta) * 2 * np.pi / 360.
# get x, y, z from known formulae
x = start_x + (r*np.cos(phi)*np.sin(theta))
y = start_y + (r*np.sin(phi)*np.sin(theta))
z = (r*np.cos(theta))

elevation = np.cumsum(z) + start_z

import vtki

well_traj_adam = vtki.PolyData(np.c_[x,y,elevation])
well_traj_adam.save('well_OH1.vtk')

well_traj_adam.plot()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x12A7E3940>

# %% [markdown]
# ## OH-4
# Coordinates: x =336732.003, y=4264165.972, z=1736.723479
#
# Lithology: Basin Fill (0-473m), Granitoid (473-537m)
#
# Depth: 537 m

# %%
depth = 537
start_x = 336732.003
start_y = 4264165.972
start_z = 1736.723479

r = np.arange(0.0, depth + 0.5, 0.5)
phi = np.zeros(len(r))
theta = np.zeros(len(r))   

for x in range(0, len(r)):
    theta[x] = -90

#Well trajectory

# get lengths of the separate segments 
r[1:] = r[1:] - r[:-1]
# convert to radians
phi = phi * 2 * np.pi / 360.
theta = (90-theta) * 2 * np.pi / 360.
# get x, y, z from known formulae
x = start_x + (r*np.cos(phi)*np.sin(theta))
y = start_y + (r*np.sin(phi)*np.sin(theta))
z = (r*np.cos(theta))

elevation = np.cumsum(z) + start_z

import vtki

well_traj_adam = vtki.PolyData(np.c_[x,y,elevation])
well_traj_adam.save('well_OH4.vtk')

well_traj_adam.plot()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x13BE92518>

# %% [markdown]
# ## OH-5
# Coordinates: x =337664.009, y=4265502.948, z=1749.584142
#
# Lithology: Basin Fill (0-144m), Granitoid (144-544.4m)
#
# Depth: 544.4 m

# %%
depth = 544.4
start_x = 337664.009
start_y = 4265502.948
start_z = 1749.584142

r = np.arange(0.0, depth + 0.5, 0.5)
phi = np.zeros(len(r))
theta = np.zeros(len(r))   

for x in range(0, len(r)):
    theta[x] = -90

#Well trajectory

# get lengths of the separate segments 
r[1:] = r[1:] - r[:-1]
# convert to radians
phi = phi * 2 * np.pi / 360.
theta = (90-theta) * 2 * np.pi / 360.
# get x, y, z from known formulae
x = start_x + (r*np.cos(phi)*np.sin(theta))
y = start_y + (r*np.sin(phi)*np.sin(theta))
z = (r*np.cos(theta))

elevation = np.cumsum(z) + start_z

import vtki

well_traj_adam = vtki.PolyData(np.c_[x,y,elevation])
well_traj_adam.save('well_OH5.vtk')

well_traj_adam.plot()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x123B2E898>

# %% [markdown]
# ## OH-7
# Coordinates: x =341498.992, y=4262178.049, z=1959.456925
#
# Lithology: Basin Fill (0-76m), Granitoid (76-609.6m)
#
# Depth: 609.6 m

# %%
depth = 609.6
start_x = 341498.992
start_y = 4262178.049
start_z = 1959.456925

r = np.arange(0.0, depth + 0.5, 0.5)
phi = np.zeros(len(r))
theta = np.zeros(len(r))   

for x in range(0, len(r)):
    theta[x] = -90

#Well trajectory

# get lengths of the separate segments 
r[1:] = r[1:] - r[:-1]
# convert to radians
phi = phi * 2 * np.pi / 360.
theta = (90-theta) * 2 * np.pi / 360.
# get x, y, z from known formulae
x = start_x + (r*np.cos(phi)*np.sin(theta))
y = start_y + (r*np.sin(phi)*np.sin(theta))
z = (r*np.cos(theta))

elevation = np.cumsum(z) + start_z

import vtki

well_traj_adam = vtki.PolyData(np.c_[x,y,elevation])
well_traj_adam.save('well_OH7.vtk')

well_traj_adam.plot()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x1314D2208>

# %% [markdown]
# ## OH-8
# Coordinates: x =339280.962, y=4259015.056, z=1935.213309
#
# Lithology: Basin Fill (0-99m), Granitoid (99-635.5m)
#
# Depth: 635.5 m

# %%
depth = 635.5
start_x = 339280.962
start_y = 4259015.056
start_z = 1935.213309

r = np.arange(0.0, depth + 0.5, 0.5)
phi = np.zeros(len(r))
theta = np.zeros(len(r))   

for x in range(0, len(r)):
    theta[x] = -90

#Well trajectory

# get lengths of the separate segments 
r[1:] = r[1:] - r[:-1]
# convert to radians
phi = phi * 2 * np.pi / 360.
theta = (90-theta) * 2 * np.pi / 360.
# get x, y, z from known formulae
x = start_x + (r*np.cos(phi)*np.sin(theta))
y = start_y + (r*np.sin(phi)*np.sin(theta))
z = (r*np.cos(theta))

elevation = np.cumsum(z) + start_z

import vtki

well_traj_adam = vtki.PolyData(np.c_[x,y,elevation])
well_traj_adam.save('well_OH8.vtk')

well_traj_adam.plot()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x1314D2710>

# %% [markdown]
# ## PPC Drilling Ridgeline
#
# Coordinates: x =343320.987,	y= 4265079.987, z=2307.724592
#
# Lithology: Granitoid
#
# Depth: 55.8 m

# %%
depth = 55.8
start_x = 343320.987
start_y = 4265079.987
start_z = 2307.724592

r = np.arange(0.0, depth + 0.5, 0.5)
phi = np.zeros(len(r))
theta = np.zeros(len(r))   

for x in range(0, len(r)):
    theta[x] = -90

#Well trajectory

# get lengths of the separate segments 
r[1:] = r[1:] - r[:-1]
# convert to radians
phi = phi * 2 * np.pi / 360.
theta = (90-theta) * 2 * np.pi / 360.
# get x, y, z from known formulae
x = start_x + (r*np.cos(phi)*np.sin(theta))
y = start_y + (r*np.sin(phi)*np.sin(theta))
z = (r*np.cos(theta))

elevation = np.cumsum(z) + start_z

import vtki

well_traj_adam = vtki.PolyData(np.c_[x,y,elevation])
well_traj_adam.save('well_PPCDR.vtk')

well_traj_adam.plot()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x1372657F0>

# %% [markdown]
# ## PPC NM Ridgeline
#
# Coordinates: x =343465.033, y=4261796.975, z=2237.064917
#
# Lithology: Granitoid
#
# Depth: 87.2 m

# %%
depth = 87.2
start_x = 343465.033
start_y = 4261796.975
start_z = 2237.064917

r = np.arange(0.0, depth + 0.5, 0.5)
phi = np.zeros(len(r))
theta = np.zeros(len(r))   

for x in range(0, len(r)):
    theta[x] = -90

#Well trajectory

# get lengths of the separate segments 
r[1:] = r[1:] - r[:-1]
# convert to radians
phi = phi * 2 * np.pi / 360.
theta = (90-theta) * 2 * np.pi / 360.
# get x, y, z from known formulae
x = start_x + (r*np.cos(phi)*np.sin(theta))
y = start_y + (r*np.sin(phi)*np.sin(theta))
z = (r*np.cos(theta))

elevation = np.cumsum(z) + start_z

import vtki

well_traj_adam = vtki.PolyData(np.c_[x,y,elevation])
well_traj_adam.save('well_PPCNR.vtk')

well_traj_adam.plot()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x1386D42E8>

# %% [markdown]
# ## PPC OB5
#
# Coordinates: x =335652.994, y=4259050.046, z=1720.246136
#
# Lithology: Basin Fill
#
# Depth: 185 m

# %% [markdown]
# ## PPC WW2
#
# Coordinates: x =332746.004, y=4259842.021, z=1625.880826
#
# Lithology: Basin Fill
#
# Depth: 115 m

# %% [markdown]
# ## PPC WW3
#
# Coordinates: x =332636.99, y=4265601.994, z=1559.834641
#
# Lithology: Basin Fill
#
# Depth: 85 m

# %% [markdown]
# ## PPC WW4
#
# Coordinates: x =333356.009, y=4265227.963, z=1580.109746
#
# Lithology: Basin Fill
#
# Depth: 55 m

# %% [markdown]
# ## PPC-2
#
# Coordinates: x =343092.977, y=4264682.01, z=2370.738988
#
# Lithology: Granitoid
#
# Depth: 90 m

# %%
depth = 90
start_x = 343092.977
start_y = 4264682.01
start_z = 2370.738988

r = np.arange(0.0, depth + 0.5, 0.5)
phi = np.zeros(len(r))
theta = np.zeros(len(r))   

for x in range(0, len(r)):
    theta[x] = -90

#Well trajectory

# get lengths of the separate segments 
r[1:] = r[1:] - r[:-1]
# convert to radians
phi = phi * 2 * np.pi / 360.
theta = (90-theta) * 2 * np.pi / 360.
# get x, y, z from known formulae
x = start_x + (r*np.cos(phi)*np.sin(theta))
y = start_y + (r*np.sin(phi)*np.sin(theta))
z = (r*np.cos(theta))

elevation = np.cumsum(z) + start_z

import vtki

well_traj_adam = vtki.PolyData(np.c_[x,y,elevation])
well_traj_adam.save('well_PPC2.vtk')

well_traj_adam.plot()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x1386D4470>

# %% [markdown]
# ## PPC-4
#
# Coordinates: x =341407.027, y=4262040.983, z=1951.476287
#
# Lithology: Basin Fill
#
# Depth: 32 m

# %% [markdown]
# ## PPC-5
#
# Coordinates: x =339373.015, y=4253572.008, z=1965.986692
#
# Lithology: Granitoid
#
# Depth: 36 m

# %%
depth = 36
start_x = 339373.015
start_y = 4253572.008
start_z = 1965.986692

r = np.arange(0.0, depth + 0.5, 0.5)
phi = np.zeros(len(r))
theta = np.zeros(len(r))   

for x in range(0, len(r)):
    theta[x] = -90

#Well trajectory

# get lengths of the separate segments 
r[1:] = r[1:] - r[:-1]
# convert to radians
phi = phi * 2 * np.pi / 360.
theta = (90-theta) * 2 * np.pi / 360.
# get x, y, z from known formulae
x = start_x + (r*np.cos(phi)*np.sin(theta))
y = start_y + (r*np.sin(phi)*np.sin(theta))
z = (r*np.cos(theta))

elevation = np.cumsum(z) + start_z

import vtki

well_traj_adam = vtki.PolyData(np.c_[x,y,elevation])
well_traj_adam.save('well_PPC5.vtk')

well_traj_adam.plot()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x13E488978>

# %% [markdown]
# ## PPC-6
#
# Coordinates: x =340260.985, y=4254040.031, z=2057.862292
#
# Lithology: Granitoid
#
# Depth: 70 m

# %%
depth = 70
start_x = 340260.985
start_y = 4254040.031
start_z = 2057.862292

r = np.arange(0.0, depth + 0.5, 0.5)
phi = np.zeros(len(r))
theta = np.zeros(len(r))   

for x in range(0, len(r)):
    theta[x] = -90

#Well trajectory

# get lengths of the separate segments 
r[1:] = r[1:] - r[:-1]
# convert to radians
phi = phi * 2 * np.pi / 360.
theta = (90-theta) * 2 * np.pi / 360.
# get x, y, z from known formulae
x = start_x + (r*np.cos(phi)*np.sin(theta))
y = start_y + (r*np.sin(phi)*np.sin(theta))
z = (r*np.cos(theta))

elevation = np.cumsum(z) + start_z

import vtki

well_traj_adam = vtki.PolyData(np.c_[x,y,elevation])
well_traj_adam.save('well_PPC6.vtk')

well_traj_adam.plot()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x13E43F320>

# %% [markdown]
# ## RHS-07
#
# Coordinates: x =337232.02, y=4259187.979, z=1789.75312
#
# Lithology: Basin Fill
#
# Depth: 145 m

# %% [markdown]
# ## RHS-102
#
# Coordinates: x =341187.983, y=4262096.05, z=1949.707159
#
# Lithology: Basin Fill
#
# Depth: 30 m

# %% [markdown]
# ## RHS-105
#
# Coordinates: x =337202.007, y=4258396.017, z=1789.08916
#
# Lithology: Basin Fill
#
# Depth: 20 m

# %% [markdown]
# ## RHS-121
#
# Coordinates: x =335648.978, y=4255600.048, z=1763.943114
#
# Lithology: Basin Fill
#
# Depth: 108 m

# %% [markdown]
# ## RHS-122
#
# Coordinates: x =339790.039, y=4262099.967, z=1922.905615
#
# Lithology: Basin Fill
#
# Depth: 30 m

# %% [markdown]
# ## RHS-15
#
# Coordinates: x =338828.019, y=4259162.016, z=1894.15275
#
# Lithology: Basin Fill
#
# Depth: 56.1 m

# %% [markdown]
# ## RHS-16
#
# Coordinates: x =336167.961, y=4266171.981, z=1667.988599
#
# Lithology: Basin Fill
#
# Depth: 145.1 m

# %% [markdown]
# ## RHS-170
#
# Coordinates: x =335030.021, y=4270733.953, z=1559.68353
#
# Lithology: Basin Fill
#
# Depth: 69 m

# %% [markdown]
# ## RHS-188
#
# Coordinates: x =338739.025, y=4263910.986, z=1833.732614
#
# Lithology: Basin Fill
#
# Depth: 60 m

# %% [markdown]
# ## RHS-189
#
# Coordinates: x =340174.978, y=4265597.04, z=1997.488738
#
# Lithology: Granitoid
#
# Depth: 89 m

# %%
depth = 89
start_x = 340174.978
start_y = 4265597.04
start_z = 1997.488738

r = np.arange(0.0, depth + 0.5, 0.5)
phi = np.zeros(len(r))
theta = np.zeros(len(r))   

for x in range(0, len(r)):
    theta[x] = -90

#Well trajectory

# get lengths of the separate segments 
r[1:] = r[1:] - r[:-1]
# convert to radians
phi = phi * 2 * np.pi / 360.
theta = (90-theta) * 2 * np.pi / 360.
# get x, y, z from known formulae
x = start_x + (r*np.cos(phi)*np.sin(theta))
y = start_y + (r*np.sin(phi)*np.sin(theta))
z = (r*np.cos(theta))

elevation = np.cumsum(z) + start_z

import vtki

well_traj_adam = vtki.PolyData(np.c_[x,y,elevation])
well_traj_adam.save('well_RHS189.vtk')

well_traj_adam.plot()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x137265668>

# %% [markdown]
# ## RHS-196
#
# Coordinates: x =335293.956, y=4255631.958, z=1751.703763
#
# Lithology: Basin Fill
#
# Depth: 109 m

# %% [markdown]
# ## RHS-199
#
# Coordinates: x =336264.978, y=4259513.051, z=1753.059889
#
# Lithology: Basin Fill
#
# Depth: 140 m

# %% [markdown]
# ## RHS-336
#
# Coordinates: x =337667.027, y=4264924.025, z=1760.117443
#
# Lithology: Basin Fill
#
# Depth: 200 m

# %% [markdown]
# ## TPC-10
#
# Coordinates: x =334032.996, y=4259944.996, z=1660.42065
#
# Lithology: Basin Fill
#
# Depth: 175 m

# %% [markdown]
# ## TPC-11
#
# Coordinates: x =337593.012, y=4261888.004, z=1818.67826
#
# Lithology: Basin Fill
#
# Depth: 63 m

# %% [markdown]
# ## TPC-15
#
# Coordinates: x =338361.029, y=4259096.017, z=1866.213434
#
# Lithology: Basin Fill
#
# Depth: 64 m

# %% [markdown]
# ## TPC-4
#
# Coordinates: x =332845.005, y=4259947.986, z=1625.700543
#
# Lithology: Basin Fill
#
# Depth: 195 m

# %% [markdown]
# ## TPC-5
#
# Coordinates: x =336275.002, y=4259383.951, z=1753.275156
#
# Lithology: Basin Fill
#
# Depth: 155 m

# %% [markdown]
# ## TPC-6
#
# Coordinates: x =339924.03, y=4261927.99, z=1927.300195
#
# Lithology: Basin Fill
#
# Depth: 105 m

# %% [markdown]
# ## TPC-7
#
# Coordinates: x =337604.973, y=4258776.986, z=1808.732258
#
# Lithology: Basin Fill
#
# Depth: 90 m

# %% [markdown]
# ## TPC-9
#
# Coordinates: x =337251.991, y=4256837.954, z=1823.425809
#
# Lithology: Basin Fill
#
# Depth: 75 m

# %% [markdown]
# ## UU-75-12
#
# Coordinates: x =337894.963, y=4266107, z=1748.109522
#
# Lithology: Basin Fill
#
# Depth: 34.5 m

# %% [markdown]
# ## UU-75-13
#
# Coordinates: x =336105.996, y=4267274.032, z=1643.731496
#
# Lithology: Basin Fill
#
# Depth: 43 m

# %% [markdown]
# ## UU-75-1A
#
# Coordinates: x =337752.963, y=4261867.006, z=1820.807353
#
# Lithology: Basin Fill
#
# Depth: 68.5 m

# %% [markdown]
# ## UU-75-1B
#
# Coordinates: x =337592.957, y=4261535.96, z=1814.525106
#
# Lithology: Basin Fill
#
# Depth: 65 m

# %% [markdown]
# ## UU-76-1A
#
# Coordinates: x =338436.97, y=4263657.056, z=1817.760172
#
# Lithology: Basin Fill
#
# Depth: 63.5 m

# %% [markdown]
# ## UUHF-3
#
# Coordinates: x =341985.97, y=4264638.026, z=2100.487344
#
# Lithology: Granitoid
#
# Depth: 150 m

# %%
depth = 150
start_x = 341985.97
start_y = 4264638.026
start_z = 2100.487344

r = np.arange(0.0, depth + 0.5, 0.5)
phi = np.zeros(len(r))
theta = np.zeros(len(r))   

for x in range(0, len(r)):
    theta[x] = -90

#Well trajectory

# get lengths of the separate segments 
r[1:] = r[1:] - r[:-1]
# convert to radians
phi = phi * 2 * np.pi / 360.
theta = (90-theta) * 2 * np.pi / 360.
# get x, y, z from known formulae
x = start_x + (r*np.cos(phi)*np.sin(theta))
y = start_y + (r*np.sin(phi)*np.sin(theta))
z = (r*np.cos(theta))

elevation = np.cumsum(z) + start_z

import vtki

well_traj_adam = vtki.PolyData(np.c_[x,y,elevation])
well_traj_adam.save('well_UUHF3.vtk')

well_traj_adam.plot()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x13E4474A8>

# %% [markdown]
# ## UUTG-0
#
# Coordinates: x =336632.035, y=4268692.031, z=1646.689721
#
# Lithology: Basin Fill
#
# Depth: 77.5 m

# %% [markdown]
# ## UUTG-1
#
# Coordinates: x =338085.014, y=4268506.981, z=1709.456679
#
# Lithology: Basin Fill
#
# Depth: 60 m

# %% [markdown]
# ## UUTG-3
#
# Coordinates: x =333920.993, y=4266715.946, z=1572.138051
#
# Lithology: Basin Fill
#
# Depth: 100 m

# %% [markdown]
# ## UUTG-5
#
# Coordinates: x =340979.035, y=4268389.045, z=1876.463274
#
# Lithology: Basin Fill
#
# Depth: 50 m

# %% [markdown]
# ## UUTG-6
#
# Coordinates: x =333698.986, y=4270118.002, z=1530.466728
#
# Lithology: Basin Fill
#
# Depth: 97.5 m
